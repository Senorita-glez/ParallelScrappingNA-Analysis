# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
#holas, ORRAR este comentario
class Scraper():

    base_url = 'https://listado.mercadolibre.com.mx/'

    def scraping(self):
        # User search
        product_name = input("\nProducto: ")
        # Clean the user input
        cleaned_name = product_name.replace(" ", "-").lower()
        # Create the urls to scrap
        urls = [self.base_url + cleaned_name]

        page_number = 50
        for i in range(0, 10000, 50):
            urls.append(f"{self.base_url}{cleaned_name}_Desde_{page_number + 1}_NoIndex_True")
            page_number += 50

        # create a list to save the data
        self.data = []
        # create counter
        c = 1
            
        # Iterate over each url
        for i, url in enumerate(urls, start=1):

            # Get the html of the page
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')
                
            # take all posts
            content = soup.find_all('li', class_='ui-search-layout__item')
            
            # Check if there's no content to scrape
            if not content:
                print("\nTermino el scraping.")
                break

            print(f"\nScrapeando pagina numero {i}. {url}")
            
            
            # iteration to scrape posts
            for post in content:

                post_link = post.find("a")["href"]

                post_data = {
                    # "title": title,
               #     "price": price,
                    "post link": post_link,
              #      "image link": img_link            
                }
                # save the dictionaries in a list
                self.data.append(post_data)
                c += 1

    def export_to_csv(self):
        # export to a csv file
        df = pd.DataFrame(self.data)
        df.to_csv(r"mercadolibre_scraped_data.csv", sep=";")

if __name__ == "__main__":
    s = Scraper()
    s.scraping()
    s.export_to_csv()
# Out:
# Scrapeando pagina numero 1. https://listado.mercadolibre.com.mx/freidora
#
# Scrapeando pagina numero 2. https://listado.mercadolibre.com.mx/freidora_Desde_51_NoIndex_True
#
# Scrapeando pagina numero 3. https://listado.mercadolibre.com.mx/freidora_Desde_101_NoIndex_True
#
# Scrapeando pagina numero 4. https://listado.mercadolibre.com.mx/freidora_Desde_151_NoIndex_True
#
# Scrapeando pagina numero 5. https://listado.mercadolibre.com.mx/freidora_Desde_201_NoIndex_True
#
# Scrapeando pagina numero 6. https://listado.mercadolibre.com.mx/freidora_Desde_251_NoIndex_True
#
# Scrapeando pagina numero 7. https://listado.mercadolibre.com.mx/freidora_Desde_301_NoIndex_True
#
# Scrapeando pagina numero 8. https://listado.mercadolibre.com.mx/freidora_Desde_351_NoIndex_True
#
# Scrapeando pagina numero 9. https://listado.mercadolibre.com.mx/freidora_Desde_401_NoIndex_True
#
# Scrapeando pagina numero 10. https://listado.mercadolibre.com.mx/freidora_Desde_451_NoIndex_True
#
# Scrapeando pagina numero 11. https://listado.mercadolibre.com.mx/freidora_Desde_501_NoIndex_True
#
# Scrapeando pagina numero 12. https://listado.mercadolibre.com.mx/freidora_Desde_551_NoIndex_True
#
# Scrapeando pagina numero 13. https://listado.mercadolibre.com.mx/freidora_Desde_601_NoIndex_True
#
# Scrapeando pagina numero 14. https://listado.mercadolibre.com.mx/freidora_Desde_651_NoIndex_True
#
# Scrapeando pagina numero 15. https://listado.mercadolibre.com.mx/freidora_Desde_701_NoIndex_True
#
# Scrapeando pagina numero 16. https://listado.mercadolibre.com.mx/freidora_Desde_751_NoIndex_True
#
# Scrapeando pagina numero 17. https://listado.mercadolibre.com.mx/freidora_Desde_801_NoIndex_True
#
# Scrapeando pagina numero 18. https://listado.mercadolibre.com.mx/freidora_Desde_851_NoIndex_True
#
# Scrapeando pagina numero 19. https://listado.mercadolibre.com.mx/freidora_Desde_901_NoIndex_True
#
# Scrapeando pagina numero 20. https://listado.mercadolibre.com.mx/freidora_Desde_951_NoIndex_True
#
# Scrapeando pagina numero 21. https://listado.mercadolibre.com.mx/freidora_Desde_1001_NoIndex_True
#
# Scrapeando pagina numero 22. https://listado.mercadolibre.com.mx/freidora_Desde_1051_NoIndex_True
#
# Scrapeando pagina numero 23. https://listado.mercadolibre.com.mx/freidora_Desde_1101_NoIndex_True
#
# Scrapeando pagina numero 24. https://listado.mercadolibre.com.mx/freidora_Desde_1151_NoIndex_True
#
# Scrapeando pagina numero 25. https://listado.mercadolibre.com.mx/freidora_Desde_1201_NoIndex_True
#
# Scrapeando pagina numero 26. https://listado.mercadolibre.com.mx/freidora_Desde_1251_NoIndex_True
#
# Scrapeando pagina numero 27. https://listado.mercadolibre.com.mx/freidora_Desde_1301_NoIndex_True
#
# Scrapeando pagina numero 28. https://listado.mercadolibre.com.mx/freidora_Desde_1351_NoIndex_True
#
# Scrapeando pagina numero 29. https://listado.mercadolibre.com.mx/freidora_Desde_1401_NoIndex_True
#
# Scrapeando pagina numero 30. https://listado.mercadolibre.com.mx/freidora_Desde_1451_NoIndex_True
#
# Scrapeando pagina numero 31. https://listado.mercadolibre.com.mx/freidora_Desde_1501_NoIndex_True
#
# Scrapeando pagina numero 32. https://listado.mercadolibre.com.mx/freidora_Desde_1551_NoIndex_True
#
# Scrapeando pagina numero 33. https://listado.mercadolibre.com.mx/freidora_Desde_1601_NoIndex_True
#
# Scrapeando pagina numero 34. https://listado.mercadolibre.com.mx/freidora_Desde_1651_NoIndex_True
#
# Scrapeando pagina numero 35. https://listado.mercadolibre.com.mx/freidora_Desde_1701_NoIndex_True
#
# Scrapeando pagina numero 36. https://listado.mercadolibre.com.mx/freidora_Desde_1751_NoIndex_True
#
# Scrapeando pagina numero 37. https://listado.mercadolibre.com.mx/freidora_Desde_1801_NoIndex_True
#
# Scrapeando pagina numero 38. https://listado.mercadolibre.com.mx/freidora_Desde_1851_NoIndex_True
#
# Scrapeando pagina numero 39. https://listado.mercadolibre.com.mx/freidora_Desde_1901_NoIndex_True
#
# Scrapeando pagina numero 40. https://listado.mercadolibre.com.mx/freidora_Desde_1951_NoIndex_True
#
# Scrapeando pagina numero 41. https://listado.mercadolibre.com.mx/freidora_Desde_2001_NoIndex_True
#
# Termino el scraping.
